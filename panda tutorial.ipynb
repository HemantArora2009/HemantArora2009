# %%
import numpy as np
import pandas as pd

# %%
dict1= {
    "name":['hemant','reya','jagriti'],
    'marks':[96,95,93],
    'city':['delhi','jharkhand','bihar']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks       city
# 0   hemant     96      delhi
# 1     reya     95  jharkhand
# 2  jagriti     93      bihar

# %%
df.to_csv('exam marks.csv')

# %%
df.to_csv('exam marks_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#      name  marks       city
# 0  hemant     96      delhi
# 1    reya     95  jharkhand

# %%
df.tail(2)
# Out:
#       name  marks       city
# 1     reya     95  jharkhand
# 2  jagriti     93      bihar

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   94.666667
# std     1.527525
# min    93.000000
# 25%    94.000000
# 50%    95.000000
# 75%    95.500000
# max    96.000000

# %%
reya = pd.read_csv('reya.csv')

# %%
reya
# Out:
#    Train No  Speed        city
# 0     12345     90       delhi
# 1     23456     95   jharkhand
# 2     34567     93       bihar
# 3     45678     94          up
# 4     56789     92  saharanpur

# %%
reya['Speed']
# Out:
# 0    90
# 1    95
# 2    93
# 3    94
# 4    92
# Name: Speed, dtype: int64

# %%
reya['Speed'][0]
# Out:
# 90

# %%
reya['Speed'][0]=100
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12784\4230447028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reya['Speed'][0]=100

# %%
reya
# Out:
#    Train No  Speed        city
# 0     12345    100       delhi
# 1     23456     95   jharkhand
# 2     34567     93       bihar
# 3     45678     94          up
# 4     56789     92  saharanpur

# %%
reya.to_csv('reya_index_false.csv',index=False)

# %%
reya.index=['first','second','third','fourth','five']

# %%
reya
# Out:
#         Train No  Speed        city
# first      12345    100       delhi
# second     23456     95   jharkhand
# third      34567     93       bihar
# fourth     45678     94          up
# five       56789     92  saharanpur

# %%
reya.index=[1,2,3,4,5]

# %%
reya
# Out:
#    Train No  Speed        city
# 1     12345    100       delhi
# 2     23456     95   jharkhand
# 3     34567     93       bihar
# 4     45678     94          up
# 5     56789     92  saharanpur

# %%
ser = pd.Series(np.random.rand(10))

# %%
ser
# Out:
# 0    0.376374
# 1    0.112008
# 2    0.715340
# 3    0.794974
# 4    0.890290
# 5    0.225370
# 6    0.908070
# 7    0.740560
# 8    0.861918
# 9    0.997217
# dtype: float64

# %%
type (ser)
# Out:
# pandas.core.series.Series

# %%
type (df)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.949484  0.468009  0.344151  0.456019  0.897977
# 1    0.175241  0.459594  0.331143  0.168537  0.845991
# 2    0.634792  0.480508  0.104973  0.245989  0.320939
# 3    0.417513  0.566445  0.553358  0.107006  0.612100
# 4    0.244784  0.028469  0.283547  0.060357  0.676535
# ..        ...       ...       ...       ...       ...
# 329  0.633549  0.113790  0.394566  0.840589  0.313941
# 330  0.474434  0.719901  0.278288  0.685843  0.576630
# 331  0.726831  0.674889  0.313687  0.587243  0.891115
# 332  0.748673  0.682100  0.915756  0.614183  0.423799
# 333  0.412582  0.756865  0.983592  0.610525  0.906017
#
# [334 rows x 5 columns]

# %%
newdf=pd.DataFrame(np.random.rand(334,5))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.472607  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4    0.688700  0.283501  0.228383  0.767000  0.139453
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742  0.198410
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0    (0, 3)  0.317603  0.645795  0.088837  0.559806
# 1  0.061682  0.504751  0.994816  0.816022  0.739009
# 2  0.143723  0.727965  0.721061  0.120191  0.710481
# 3  0.834484  0.932878  0.088784  0.066874  0.882521
# 4    0.6887  0.283501  0.228383  0.767000    (0, 3)

# %%
newdf[0]
# Out:
# 0        (0, 3)
# 1      0.061682
# 2      0.143723
# 3      0.834484
# 4        0.6887
#          ...
# 329    0.999593
# 330    0.722764
# 331    0.094067
# 332    0.232896
# 333    0.948059
# Name: 0, Length: 334, dtype: object

# %%
newdf2 = newdf

# %%
newdf2[0][0] = 9832
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12784\2229558824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0] = 9832

# %%
newdf
# Out:
#             0         1         2         3         4
# 0        9832  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
newdf.columns=list('abcde')

# %%
newdf
# Out:
#             a         b         c         d         e
# 0        9832  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0] = 654

# %%
newdf.head()
# Out:
#           a         b         c         d         e      0
# 0      9832  0.317603  0.645795  0.088837  0.559806  654.0
# 1  0.061682  0.504751  0.994816  0.816022  0.739009    NaN
# 2  0.143723  0.727965  0.721061  0.120191  0.710481    NaN
# 3  0.834484  0.932878  0.088784  0.066874  0.882521    NaN
# 4    0.6887  0.283501  0.228383  0.767000    (0, 3)    NaN

# %%
newdf.drop(0,axis=1)
# Out:
#             a         b         c         d         e
# 0        9832  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2],['c','d']]
# Out:
#           c         d
# 1  0.994816  0.816022
# 2  0.721061  0.120191

# %%
newdf.loc[[1,2],['c','d']]

# %%
newdf.loc[:,['c','d']]
# Out:
#             c         d
# 0    0.645795  0.088837
# 1    0.994816  0.816022
# 2    0.721061  0.120191
# 3    0.088784  0.066874
# 4    0.228383  0.767000
# ..        ...       ...
# 329  0.613986  0.017919
# 330  0.389441  0.124503
# 331  0.922536  0.916378
# 332  0.919716  0.490334
# 333  0.228774  0.595742
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           a         b         c         d         e   0
# 1  0.061682  0.504751  0.994816  0.816022  0.739009 NaN
# 2  0.143723  0.727965  0.721061  0.120191  0.710481 NaN

# %%
newdf.loc[(newdf['a']<0.3)]
# Out:
#             a         b         c         d         e   0
# 1    0.061682  0.504751  0.994816  0.816022  0.739009 NaN
# 2    0.143723  0.727965  0.721061  0.120191  0.710481 NaN
# 6    0.141234  0.447143  0.685271  0.180086  0.765683 NaN
# 7    0.160863  0.428255  0.182272  0.364963  0.565741 NaN
# 9    0.244664  0.706289  0.767466  0.303276  0.513899 NaN
# ..        ...       ...       ...       ...       ...  ..
# 325  0.282365  0.898563  0.239410  0.046396  0.291099 NaN
# 327  0.089435  0.799196  0.886570  0.420352  0.750078 NaN
# 328  0.154487  0.956942  0.767617  0.348629  0.487863 NaN
# 331  0.094067  0.083752  0.922536  0.916378  0.062931 NaN
# 332  0.232896  0.501232  0.919716  0.490334  0.582633 NaN
#
# [111 rows x 6 columns]

# %%
newdf.loc[(newdf['a']<0.3) & (newdf['c']>0.1)]
# Out:
#             a         b         c         d         e   0
# 1    0.061682  0.504751  0.994816  0.816022  0.739009 NaN
# 2    0.143723  0.727965  0.721061  0.120191  0.710481 NaN
# 6    0.141234  0.447143  0.685271  0.180086  0.765683 NaN
# 7    0.160863  0.428255  0.182272  0.364963  0.565741 NaN
# 9    0.244664  0.706289  0.767466  0.303276  0.513899 NaN
# ..        ...       ...       ...       ...       ...  ..
# 325  0.282365  0.898563  0.239410  0.046396  0.291099 NaN
# 327  0.089435  0.799196  0.886570  0.420352  0.750078 NaN
# 328  0.154487  0.956942  0.767617  0.348629  0.487863 NaN
# 331  0.094067  0.083752  0.922536  0.916378  0.062931 NaN
# 332  0.232896  0.501232  0.919716  0.490334  0.582633 NaN
#
# [103 rows x 6 columns]

# %%
newdf.iloc[[1,2],[2,3]]
# Out:
#           c         d
# 1  0.994816  0.816022
# 2  0.721061  0.120191

# %%
newdf.drop([0])
# Out:
#             a         b         c         d         e   0
# 1    0.061682  0.504751  0.994816  0.816022  0.739009 NaN
# 2    0.143723  0.727965  0.721061  0.120191  0.710481 NaN
# 3    0.834484  0.932878  0.088784  0.066874  0.882521 NaN
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3) NaN
# 5    0.466275  0.858138  0.281233  0.565276  0.439116 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.999593  0.545229  0.613986  0.017919  0.052635 NaN
# 330  0.722764  0.262170  0.389441  0.124503  0.685833 NaN
# 331  0.094067  0.083752  0.922536  0.916378  0.062931 NaN
# 332  0.232896  0.501232  0.919716  0.490334  0.582633 NaN
# 333  0.948059  0.846729  0.228774  0.595742   0.19841 NaN
#
# [333 rows x 6 columns]

# %%
newdf.drop([0],axis=1)
# Out:
#             a         b         c         d         e
# 0        9832  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
newdf.drop([0],axis=1,inplace=True)

# %%
newdf
# Out:
#             a         b         c         d         e
# 0        9832  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
newdf.reset_index()
# Out:
#      index         a         b         c         d         e
# 0        0      9832  0.317603  0.645795  0.088837  0.559806
# 1        1  0.061682  0.504751  0.994816  0.816022  0.739009
# 2        2  0.143723  0.727965  0.721061  0.120191  0.710481
# 3        3  0.834484  0.932878  0.088784  0.066874  0.882521
# 4        4    0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..     ...       ...       ...       ...       ...       ...
# 329    329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330    330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331    331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332    332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333    333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 6 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             a         b         c         d         e
# 0        9832  0.317603  0.645795  0.088837  0.559806
# 1    0.061682  0.504751  0.994816  0.816022  0.739009
# 2    0.143723  0.727965  0.721061  0.120191  0.710481
# 3    0.834484  0.932878  0.088784  0.066874  0.882521
# 4      0.6887  0.283501  0.228383  0.767000    (0, 3)
# ..        ...       ...       ...       ...       ...
# 329  0.999593  0.545229  0.613986  0.017919  0.052635
# 330  0.722764  0.262170  0.389441  0.124503  0.685833
# 331  0.094067  0.083752  0.922536  0.916378  0.062931
# 332  0.232896  0.501232  0.919716  0.490334  0.582633
# 333  0.948059  0.846729  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
newdf['b']=None

# %%
newdf
# Out:
#             a     b         c         d         e
# 0        9832  None  0.645795  0.088837  0.559806
# 1    0.061682  None  0.994816  0.816022  0.739009
# 2    0.143723  None  0.721061  0.120191  0.710481
# 3    0.834484  None  0.088784  0.066874  0.882521
# 4      0.6887  None  0.228383  0.767000    (0, 3)
# ..        ...   ...       ...       ...       ...
# 329  0.999593  None  0.613986  0.017919  0.052635
# 330  0.722764  None  0.389441  0.124503  0.685833
# 331  0.094067  None  0.922536  0.916378  0.062931
# 332  0.232896  None  0.919716  0.490334  0.582633
# 333  0.948059  None  0.228774  0.595742   0.19841
#
# [334 rows x 5 columns]

# %%
df = pd.DataFrame({"name": ['hemant','ravi'],
                  "toy": [np.nan, 'Batmobile'],
                  "born": [1995,1995]})

# %%
df
# Out:
#      name        toy  born
# 0  hemant        NaN  1995
# 1    ravi  Batmobile  1995

# %%
df.drop_duplicates(subset=["born"])
# Out:
#      name  toy  born
# 0  hemant  NaN  1995

# %%
df.drop_duplicates(subset=["born"], keep='first')
# Out:
#      name  toy  born
# 0  hemant  NaN  1995

# %%
df.drop_duplicates(subset=["born"], keep=False)
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
df.shape
# Out:
# (2, 3)

# %%
df.info
# Out:
# <bound method DataFrame.info of      name        toy  born
# 0  hemant        NaN  1995
# 1    ravi  Batmobile  1995>

# %%
df['born'].value_counts(dropna=False)
# Out:
# 1995    2
# Name: born, dtype: int64

# %%
df['born'].value_counts(dropna=True)
# Out:
# 1995    2
# Name: born, dtype: int64

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True  False
# 1  False  False  False

# %%
df.notnull()
# Out:
#    name    toy  born
# 0  True  False  True
# 1  True   True  True

# %%
a=20
print(a)
# Out:
# 20

# %%
# create a dataframe which contains only integers with 3 rows and 2 columns
# run following dataframe methods on them:
df.describe()
df.mean()
df.corr()
df.count()
df.max()
df.min()
df.median()
df.std()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12784\2024749118.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# C:\Users\hp\AppData\Local\Temp\ipykernel_12784\2024749118.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# C:\Users\hp\AppData\Local\Temp\ipykernel_12784\2024749118.py:7: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
data= pd.read_excel('train numbers.xlsx')

# %%
data
# Out:
#    Train No  Speed        city
# 0     12345    100       delhi
# 1     23456     95   jharkhand
# 2     34567     93       bihar
# 3     45678     94          up
# 4     56789     92  saharanpur

# %%
data= pd.read_excel('train numbers.xlsx',sheet_name='sheet1')

# %%
data
# Out:
#    Train No  Speed        city
# 0     12345    100       delhi
# 1     23456     95   jharkhand
# 2     34567     93       bihar
# 3     45678     94          up
# 4     56789     92  saharanpur

# %%
data= pd.read_excel('train numbers.xlsx',sheet_name='Sheet2')

# %%
data
# Out:
#    Train No  Speed        city
# 0     12345    100       delhi
# 1     68844     95   jharkhand
# 2     34567    120       bihar
# 3     78903    110   begusarai
# 4     56789     92  saharanpur

# %%
data.iloc[0,0] = 34

# %%
data
# Out:
#    Train No  Speed        city
# 0        34    100       delhi
# 1     68844     95   jharkhand
# 2     34567    120       bihar
# 3     78903    110   begusarai
# 4     56789     92  saharanpur

# %%
data.to_excel('train numbers.xlsx', sheet_name ='Sheet2')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 data.to_excel('train numbers.xlsx', sheet_name ='Sheet2')
#
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
# create a dataframe which contains only integers with 3 rows and 2 columns
# run following dataframe methods on them:
df.describe()
df.mean()
df.corr()
df.count()
df.max()
df.min()
df.median()
df.std()

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(dict2)

# %%
dict2 = {
    "store code": [96,97,98],
    "store lode": [98,99,22]
}

# %%
df=pd.DataFrame(dict2)

# %%
df
# Out:
#    store code  store lode
# 0          96          98
# 1          97          99
# 2          98          22

# %%
df.to_csv('reya1.csv')

# %%
df.to_csv('reya1.csv', index= False)

# %%
df
# Out:
#    store code  store lode
# 0          96          98
# 1          97          99
# 2          98          22

# %%
df.head()
# Out:
#    store code  store lode
# 0          96          98
# 1          97          99
# 2          98          22

# %%
df.head(1)
# Out:
#    store code  store lode
# 0          96          98

# %%
df.tail(1)
# Out:
#    store code  store lode
# 2          98          22

# %%
df.describe()
# Out:
#        store code  store lode
# count         3.0    3.000000
# mean         97.0   73.000000
# std           1.0   44.170126
# min          96.0   22.000000
# 25%          96.5   60.000000
# 50%          97.0   98.000000
# 75%          97.5   98.500000
# max          98.0   99.000000

# %%
df.mean()
# Out:
# store code    97.0
# store lode    73.0
# dtype: float64

# %%
df.corr()
# Out:
#             store code  store lode
# store code     1.00000    -0.86031
# store lode    -0.86031     1.00000

# %%
df.count()
# Out:
# store code    3
# store lode    3
# dtype: int64

# %%
df.max()
# Out:
# store code    98
# store lode    99
# dtype: int64

# %%
df.min()
# Out:
# store code    96
# store lode    22
# dtype: int64

# %%
df.median()
# Out:
# store code    97.0
# store lode    98.0
# dtype: float64

# %%
df.std()
# Out:
# store code     1.000000
# store lode    44.170126
# dtype: float64

# %%
reya1 = pd.read_csv('reya1.csv')

# %%
reya1
# Out:
#    store code  store lode
# 0          96          98
# 1          97          99
# 2          98          22

# %%
reya1['store code']
# Out:
# 0    96
# 1    97
# 2    98
# Name: store code, dtype: int64

# %%
reya1['store code'][0]=30

# %%
reya1
# Out:
#    store code  store lode
# 0          30          98
# 1          97          99
# 2          98          22

# %%
reya1.to_csv('reya1.csv')

# %%
reya1.index= [2,3,4]

# %%
reya1
# Out:
#    store code  store lode
# 2          30          98
# 3          97          99
# 4          98          22

# %%
reya1.to_numpy
# Out:
# <bound method DataFrame.to_numpy of    store code  store lode
# 2          30          98
# 3          97          99
# 4          98          22>

# %%
reya1['store code'][0] = (0,3)

# %%
reya1
# Out:
#    store code  store lode
# 2          30          98
# 3          97          99
# 4          98          22

# %%
reya1.T
# Out:
#              2   3   4
# store code  30  97  98
# store lode  98  99  22

# %%
reya1.sort_index(axis=0,ascending=False)
# Out:
#    store code  store lode
# 4          98          22
# 3          97          99
# 2          30          98

# %%
reya1.sort_index(axis=0,ascending=True)
# Out:
#    store code  store lode
# 2          30          98
# 3          97          99
# 4          98          22

# %%
reya1.sort_index(axis=1,ascending=False)
# Out:
#    store lode  store code
# 2          98          30
# 3          99          97
# 4          22          98

# %%
reya1.loc['store code',0]=654

# %%
reya1
# Out:
#             store code  store lode      0
# 2                 30.0        98.0    NaN
# 3                 97.0        99.0    NaN
# 4                 98.0        22.0    NaN
# store code         NaN         NaN  654.0

# %%
reya1.drop(0,axis=1)
# Out:
#             store code  store lode
# 2                 30.0        98.0
# 3                 97.0        99.0
# 4                 98.0        22.0
# store code         NaN         NaN

# %%
reya1.drop('store code',axis=1)
# Out:
#             store lode      0
# 2                 98.0    NaN
# 3                 99.0    NaN
# 4                 22.0    NaN
# store code         NaN  654.0

# %%
reya1
# Out:
#             store code  store lode      0
# 2                 30.0        98.0    NaN
# 3                 97.0        99.0    NaN
# 4                 98.0        22.0    NaN
# store code         NaN         NaN  654.0

# %%
reya1.loc[[2,3],['store code','store lode']]
# Out:
#    store code  store lode
# 2        30.0        98.0
# 3        97.0        99.0

# %%
reya1.loc[:,['store code','store lode']]
# Out:
#             store code  store lode
# 2                 30.0        98.0
# 3                 97.0        99.0
# 4                 98.0        22.0
# store code         NaN         NaN

# %%
reya1.loc[[2,3],:]
# Out:
#    store code  store lode   0
# 2        30.0        98.0 NaN
# 3        97.0        99.0 NaN

# %%
reya1.loc[(reya1['store code']<97,98)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 98
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
reya1.iloc[[0,4],[1,2]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 reya1.iloc[[0,4],[1,2]]
#
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File G:\Users\hp\anaconda3\lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...
